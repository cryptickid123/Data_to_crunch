# %%
# %sql
Create table pramoddatabricks.control.bronze_control(
    source_name string,
    source_path string,
    source_file string,
    target_table string,
    load_type string)

# %%
spark.sql("""
          Insert into pramoddatabricks.control.bronze_control
          Values("participant","landing/participant","participant_master_*.csv","bronze_participant","INCREMENTAL")
          """)
