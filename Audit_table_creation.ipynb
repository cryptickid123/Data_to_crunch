# %%
dbutils.widgets.text("pipline_name", "")
dbutils.widgets.text("run_id", "")
dbutils.widgets.text("file_name", "")
dbutils.widgets.text("pipline_status", "")
dbutils.widgets.text("pipline_start_time", "")
dbutils.widgets.text("pipline_end_time", "")
dbutils.widgets.text("error_message", "")
dbutils.widgets.text("file_path", "")

# %%
pipline_name = dbutils.widgets.get("pipline_name")
run_id = dbutils.widgets.get("run_id")
file_name = dbutils.widgets.get("file_name")
pipline_status = dbutils.widgets.get("pipline_status")
pipline_start_time = dbutils.widgets.get("pipline_start_time")
pipline_end_time = dbutils.widgets.get("pipline_end_time")
error_message = dbutils.widgets.get("error_message")
file_path = dbutils.widgets.get("file_path")

# %%
# %sql
use catalog pramoddatabricks

# %%
# %sql
create schema if not exists pramoddatabricks.control

# %%
# %sql
create table if not exists pramoddatabricks.control.audit_log(
    pipline_name string,
    run_id string,
    file_name string,
    pipline_status string,
    pipline_start_time timestamp,
    pipline_end_time timestamp,
    error_message string,
    file_path string

)

# %%
spark.sql(f"""
          Insert into pramoddatabricks.control.audit_log values('{pipline_name}','{run_id}','{file_name}','{pipline_status}','{pipline_start_time}','{pipline_end_time}','{error_message}','{file_path}'
)
 """)
